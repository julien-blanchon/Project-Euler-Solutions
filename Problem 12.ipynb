# %% [markdown]
# # Highly divisible triangular number
#
# ## Problem 12

# %% [markdown]
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
#  1: 1
#
#  3: 1,3
#
#  6: 1,2,3,6
#
# 10: 1,2,5,10
#
# 15: 1,3,5,15
#
# 21: 1,3,7,21
#
# 28: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %% [markdown]
# # Idea
#
# triangle number are Σk with k∈ℤ so the n^th triangle number is equal to t=n(n+1)/2 (with young gauss formula) so D(t) = D(n(n+1))+1

# %%
def divisor(nb):
    result = []
    for b in range(1,int(nb**0.5)+1):
        q, r = divmod(nb,b) # nb = b*q + r 
        if r == 0: # nb = bq
            if b!=q:
                result.append(b)
                result.append(q)
            else:
                result.append(b)
    return result

# %%
n=1
while len(divisor((n*(n+1))//2))<500:
    n=n+1

# %%
int(n*(n+1)/2)
# Out:
# 76576500

# %%
solution
# Out:
# [[384, 2079],
#  [320, 2639],
#  [288, 2975],
#  [288, 2925],
#  [288, 2015],
#  [256, 2375],
#  [256, 2295],
#  [256, 2184],
#  [240, 2960],
#  [240, 2736],
#  [240, 2024],
#  [240, 1539],
#  [224, 2624],
#  [224, 2240],
#  [224, 1728],
#  [216, 2924],
#  [216, 2600],
#  [216, 2204],
#  [216, 1700],
#  [216, 1224],
#  [200, 1295],
#  [192, 2904],
#  [192, 2870],
#  [192, 2849],
#  [192, 2820],
#  [192, 2744],
#  [192, 2664],
#  [192, 2583],
#  [192, 2519],
#  [192, 2484],
#  [192, 2464],
#  [192, 2430],
#  [192, 2379],
#  [192, 2232],
#  [192, 2175],
#  [192, 2144],
#  [192, 1880],
#  [192, 1715],
#  [192, 1664],
#  [192, 1595],
#  [192, 1484],
#  [192, 1364],
#  [192, 1287],
#  [180, 2799],
#  [180, 2499],
#  [180, 2400],
#  [180, 1935],
#  [180, 1520],
#  [168, 2915],
#  [168, 2880],
#  [168, 1599],
#  [168, 1215],
#  [162, 2303],
#  [160, 2834],
#  [160, 2754],
#  [160, 2640],
#  [160, 2415],
#  [160, 2288],
#  [160, 2255],
#  [160, 2159],
#  [160, 2064],
#  [160, 2000],
# ...
