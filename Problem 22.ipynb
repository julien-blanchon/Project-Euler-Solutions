# %% [markdown]
# # Names scores
# ## Problem 22

# %% [markdown]
# Using names.txt (right click and 'Save Link/Target As...'), a 46K text file containing over five-thousand first names, begin by sorting it into alphabetical order. Then working out the alphabetical value for each name, multiply this value by its alphabetical position in the list to obtain a name score.
#
# For example, when the list is sorted into alphabetical order, COLIN, which is worth 3 + 15 + 12 + 9 + 14 = 53, is the 938th name in the list. So, COLIN would obtain a score of 938 × 53 = 49714.
#
# What is the total of all the name scores in the file?

# %%
try:
    file_path = r'Problem 22.txt'
   
   # open file in write mode
    with open(file_path, 'r') as f:
        name_list = str(f.read())
        name_list = list(name_list.split('","'))
        name_list[0] = name_list[0][1:len(name_list[0])]
        name_list[-1] = name_list[-1][0:-1]
        name_list = sorted(name_list)
        score = 0
        for pos, name in enumerate(name_list):
            letter_score = 0
            for letter in name:
                letter_score += int("_ABCDEFGHIJKLMNOPQRSTUVWXYZ".index(letter))
            score += (pos+1)*letter_score
                
except Exception as e:
    print(e)
# Out:
# 1
# AARON
# 49
# 2
# ABBEY
# 35
# 3
# ABBIE
# 19
# 4
# ABBY
# 30
# 5
# ABDUL
# 40
# 6
# ABE
# 8
# 7
# ABEL
# 20
# 8
# ABIGAIL
# 41
# 9
# ABRAHAM
# 44
# 10
# ABRAM
# 35
# 11
# ADA
# 6
# 12
# ADAH
# 14
# 13
# ADALBERTO
# 78
# 14
# ADALINE
# 46
# 15
# ADAM
# 19
# 16
# ADAN
# 20
# 17
# ADDIE
# 23
# 18
# ADELA
# 23
# 19
# ADELAIDA
# 37
# 20
# ADELAIDE
# 41
# 21
# ADELE
# 27
# 22
# ADELIA
# 32
# 23
# ADELINA
# 46
# 24
# ADELINE
# 50
# 25
# ADELL
# 34
# 26
# ADELLA
# 35
# 27
# ADELLE
# 39
# 28
# ADENA
# 25
# 29
# ADINA
# 29
# 30
# ADOLFO
# 53
# 31
# ADOLPH
# 56
# 32
# ADRIA
# 33
# 33
# ADRIAN
# 47
# 34
# ADRIANA
# 48
# 35
# ADRIANE
# 52
# 36
# ADRIANNA
# 62
# 37
# ADRIANNE
# 66
# 38
# ADRIEN
# 51
# 39
# ADRIENE
# 56
# 40
# ADRIENNE
# 70
# 41
# AFTON
# 56
# 42
# AGATHA
# 38
# 43
# AGNES
# 46
# 44
# AGNUS
# 62
# 45
# AGRIPINA
# 75
# 46
# AGUEDA
# 39
# 47
# AGUSTIN
# 91
# 48
# AGUSTINA
# 92
# 49
# AHMAD
# 27
# 50
# AHMED
# 31
# 51
# AI
# 10
# 52
# AIDA
# 15
# 53
# AIDE
# 19
# 54
# AIKO
# 36
# ...

# %%
score
# Out:
# 871198282

# %%
name_list
# Out:
# ['"MARY',
#  'PATRICIA',
#  'LINDA',
#  'BARBARA',
#  'ELIZABETH',
#  'JENNIFER',
#  'MARIA',
#  'SUSAN',
#  'MARGARET',
#  'DOROTHY',
#  'LISA',
#  'NANCY',
#  'KAREN',
#  'BETTY',
#  'HELEN',
#  'SANDRA',
#  'DONNA',
#  'CAROL',
#  'RUTH',
#  'SHARON',
#  'MICHELLE',
#  'LAURA',
#  'SARAH',
#  'KIMBERLY',
#  'DEBORAH',
#  'JESSICA',
#  'SHIRLEY',
#  'CYNTHIA',
#  'ANGELA',
#  'MELISSA',
#  'BRENDA',
#  'AMY',
#  'ANNA',
#  'REBECCA',
#  'VIRGINIA',
#  'KATHLEEN',
#  'PAMELA',
#  'MARTHA',
#  'DEBRA',
#  'AMANDA',
#  'STEPHANIE',
#  'CAROLYN',
#  'CHRISTINE',
#  'MARIE',
#  'JANET',
#  'CATHERINE',
#  'FRANCES',
#  'ANN',
#  'JOYCE',
#  'DIANE',
#  'ALICE',
#  'JULIE',
#  'HEATHER',
#  'TERESA',
#  'DORIS',
#  'GLORIA',
#  'EVELYN',
#  'JEAN',
#  'CHERYL',
#  'MILDRED',
#  'KATHERINE',
#  'JOAN',
#  'ASHLEY',
#  'JUDITH',
#  'ROSE',
#  'JANICE',
#  'KELLY',
#  'NICOLE',
#  'JUDY',
#  'CHRISTINA',
#  'KATHY',
#  'THERESA',
#  'BEVERLY',
#  'DENISE',
#  'TAMMY',
#  'IRENE',
# ...
