# %%
from __future__ import print_function
import datetime
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

# If modifying these scopes, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/calendar.readonly']

"""Shows basic usage of the Google Calendar API.
Prints the start and name of the next 10 events on the user's calendar.
"""
creds = None
# The file token.pickle stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.pickle'):
    with open('token.pickle', 'rb') as token:
        creds = pickle.load(token)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)

service = build('calendar', 'v3', credentials=creds)

# Call the Calendar API
now = datetime.datetime.utcnow().isoformat()  + 'Z' # 'Z' indicates UTC time
print('Getting the upcoming 10 events')
events_result = service.events().list(calendarId='primary', timeMin=now,
                                    maxResults=10, singleEvents=True,
                                    orderBy='startTime').execute()
events = events_result.get('items', [])

if not events:
    print('No upcoming events found.')
for event in events:
    start = event['start'].get('dateTime', event['start'].get('date'))
    print(start, event['summary'])
# Out:
# Getting the upcoming 10 events
# 2019-09-14T09:00:00+02:00 Appeler Kiné
# 2019-09-26 Pas Kinou
# 2019-09-27 Pas Kinou
# 2019-10-03 Pas Kinou
# 2019-10-04 Facture Hetzner €27.23
# 2019-11-04 Facture Hetzner €27.23
# 2019-12-04 Facture Hetzner €27.23
# 2020-01-04 Facture Hetzner €27.23
# 2020-02-04 Facture Hetzner €27.23
# 2020-03-04 Facture Hetzner €27.23

# %%
service.events().list(calendarId='primary', timeMin=now,
                                    maxResults=10, singleEvents=True,
                                    orderBy='startTime').execute()
# Out:
# {'kind': 'calendar#events',
#  'etag': '"p33kbvh5fqf7e80g"',
#  'summary': 'julien@blanchon.cc',
#  'updated': '2019-09-13T20:36:37.377Z',
#  'timeZone': 'Europe/Paris',
#  'accessRole': 'owner',
#  'defaultReminders': [{'method': 'popup', 'minutes': 10}],
#  'nextPageToken': 'Ei4KIzFsaGFqdTkzdm9oa2NhbWYycDFrbWxsOTFqXzIwMjAwMzA0GIDA68_B_-cC',
#  'items': [{'kind': 'calendar#event',
#    'etag': '"3136808593390000"',
#    'id': '4r1g2nstnhct3mjfoul7simner',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=NHIxZzJuc3RuaGN0M21qZm91bDdzaW1uZXIganVsaWVuQGJsYW5jaG9uLmNj',
#    'created': '2019-09-13T19:51:33.000Z',
#    'updated': '2019-09-13T19:51:36.695Z',
#    'summary': 'Appeler Kiné',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'dateTime': '2019-09-14T09:00:00+02:00'},
#    'end': {'dateTime': '2019-09-14T09:30:00+02:00'},
#    'iCalUID': '4r1g2nstnhct3mjfoul7simner@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True}},
#   {'kind': 'calendar#event',
#    'etag': '"3136532318264000"',
#    'id': '6or34o9m6or62bb169i3eb9k68oj6b9o6hj62bb66oo3iob174p3ic9pcg',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=Nm9yMzRvOW02b3I2MmJiMTY5aTNlYjlrNjhvajZiOW82aGo2MmJiNjZvbzNpb2IxNzRwM2ljOXBjZyBqdWxpZW5AYmxhbmNob24uY2M',
#    'created': '2019-09-12T05:29:19.000Z',
#    'updated': '2019-09-12T05:29:19.132Z',
#    'summary': 'Pas Kinou',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'date': '2019-09-26'},
#    'end': {'date': '2019-09-27'},
#    'transparency': 'transparent',
#    'iCalUID': '6or34o9m6or62bb169i3eb9k68oj6b9o6hj62bb66oo3iob174p3ic9pcg@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': False,
#     'overrides': [{'method': 'popup', 'minutes': 240}]}},
#   {'kind': 'calendar#event',
#    'etag': '"3136532334090000"',
#    'id': '6lhj0oppcpj68b9icgq6cb9kcpj3cbb26di3eb9kccpjeo9h6gq6aohp74',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=NmxoajBvcHBjcGo2OGI5aWNncTZjYjlrY3BqM2NiYjI2ZGkzZWI5a2NjcGplbzloNmdxNmFvaHA3NCBqdWxpZW5AYmxhbmNob24uY2M',
#    'created': '2019-09-12T05:29:27.000Z',
#    'updated': '2019-09-12T05:29:27.045Z',
#    'summary': 'Pas Kinou',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'date': '2019-09-27'},
#    'end': {'date': '2019-09-28'},
#    'transparency': 'transparent',
#    'iCalUID': '6lhj0oppcpj68b9icgq6cb9kcpj3cbb26di3eb9kccpjeo9h6gq6aohp74@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': False,
#     'overrides': [{'method': 'popup', 'minutes': 240}]}},
#   {'kind': 'calendar#event',
#    'etag': '"3136532397874000"',
#    'id': '74q3gp9i6hi30b9m75gjcb9k6kr3ibb2ckrjab9g70qj0c31c4sm2c9n6c',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=NzRxM2dwOWk2aGkzMGI5bTc1Z2pjYjlrNmtyM2liYjJja3JqYWI5ZzcwcWowYzMxYzRzbTJjOW42YyBqdWxpZW5AYmxhbmNob24uY2M',
#    'created': '2019-09-12T05:29:58.000Z',
#    'updated': '2019-09-12T05:29:58.937Z',
#    'summary': 'Pas Kinou',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'date': '2019-10-03'},
#    'end': {'date': '2019-10-04'},
#    'transparency': 'transparent',
#    'iCalUID': '74q3gp9i6hi30b9m75gjcb9k6kr3ibb2ckrjab9g70qj0c31c4sm2c9n6c@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': False,
#     'overrides': [{'method': 'popup', 'minutes': 240}]}},
#   {'kind': 'calendar#event',
#    'etag': '"3105779218368000"',
#    'id': '1lhaju93vohkcamf2p1kmll91j_20191004',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWxoYWp1OTN2b2hrY2FtZjJwMWttbGw5MWpfMjAxOTEwMDQganVsaWVuQGJsYW5jaG9uLmNj',
#    'created': '2018-09-28T18:51:45.000Z',
#    'updated': '2019-09-04T17:35:12.867Z',
#    'summary': 'Facture Hetzner €27.23',
#    'description': '<a href="https://accounts.hetzner.com/invoice">https://accounts.hetzner.com/invoice</a>',
#    'location': 'Gunzenhausen, 91710 Gunzenhausen, Allemagne',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'date': '2019-10-04'},
#    'end': {'date': '2019-10-05'},
#    'recurringEventId': '1lhaju93vohkcamf2p1kmll91j',
#    'originalStartTime': {'date': '2019-10-04'},
#    'transparency': 'transparent',
#    'iCalUID': '1lhaju93vohkcamf2p1kmll91j@google.com',
#    'sequence': 0,
#    'extendedProperties': {'private': {'everyoneDeclinedDismissed': '-1'}},
#    'reminders': {'useDefault': False}},
#   {'kind': 'calendar#event',
#    'etag': '"3105779218368000"',
#    'id': '1lhaju93vohkcamf2p1kmll91j_20191104',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWxoYWp1OTN2b2hrY2FtZjJwMWttbGw5MWpfMjAxOTExMDQganVsaWVuQGJsYW5jaG9uLmNj',
#    'created': '2018-09-28T18:51:45.000Z',
#    'updated': '2019-09-04T17:35:12.867Z',
#    'summary': 'Facture Hetzner €27.23',
#    'description': '<a href="https://accounts.hetzner.com/invoice">https://accounts.hetzner.com/invoice</a>',
#    'location': 'Gunzenhausen, 91710 Gunzenhausen, Allemagne',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'date': '2019-11-04'},
#    'end': {'date': '2019-11-05'},
#    'recurringEventId': '1lhaju93vohkcamf2p1kmll91j',
#    'originalStartTime': {'date': '2019-11-04'},
#    'transparency': 'transparent',
#    'iCalUID': '1lhaju93vohkcamf2p1kmll91j@google.com',
#    'sequence': 0,
#    'extendedProperties': {'private': {'everyoneDeclinedDismissed': '-1'}},
#    'reminders': {'useDefault': False}},
#   {'kind': 'calendar#event',
#    'etag': '"3105779218368000"',
#    'id': '1lhaju93vohkcamf2p1kmll91j_20191204',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWxoYWp1OTN2b2hrY2FtZjJwMWttbGw5MWpfMjAxOTEyMDQganVsaWVuQGJsYW5jaG9uLmNj',
#    'created': '2018-09-28T18:51:45.000Z',
#    'updated': '2019-09-04T17:35:12.867Z',
#    'summary': 'Facture Hetzner €27.23',
#    'description': '<a href="https://accounts.hetzner.com/invoice">https://accounts.hetzner.com/invoice</a>',
#    'location': 'Gunzenhausen, 91710 Gunzenhausen, Allemagne',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'date': '2019-12-04'},
#    'end': {'date': '2019-12-05'},
#    'recurringEventId': '1lhaju93vohkcamf2p1kmll91j',
#    'originalStartTime': {'date': '2019-12-04'},
#    'transparency': 'transparent',
#    'iCalUID': '1lhaju93vohkcamf2p1kmll91j@google.com',
#    'sequence': 0,
#    'extendedProperties': {'private': {'everyoneDeclinedDismissed': '-1'}},
#    'reminders': {'useDefault': False}},
#   {'kind': 'calendar#event',
#    'etag': '"3105779218368000"',
#    'id': '1lhaju93vohkcamf2p1kmll91j_20200104',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWxoYWp1OTN2b2hrY2FtZjJwMWttbGw5MWpfMjAyMDAxMDQganVsaWVuQGJsYW5jaG9uLmNj',
#    'created': '2018-09-28T18:51:45.000Z',
#    'updated': '2019-09-04T17:35:12.867Z',
#    'summary': 'Facture Hetzner €27.23',
#    'description': '<a href="https://accounts.hetzner.com/invoice">https://accounts.hetzner.com/invoice</a>',
#    'location': 'Gunzenhausen, 91710 Gunzenhausen, Allemagne',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'date': '2020-01-04'},
#    'end': {'date': '2020-01-05'},
#    'recurringEventId': '1lhaju93vohkcamf2p1kmll91j',
#    'originalStartTime': {'date': '2020-01-04'},
#    'transparency': 'transparent',
#    'iCalUID': '1lhaju93vohkcamf2p1kmll91j@google.com',
#    'sequence': 0,
#    'extendedProperties': {'private': {'everyoneDeclinedDismissed': '-1'}},
#    'reminders': {'useDefault': False}},
#   {'kind': 'calendar#event',
#    'etag': '"3105779218368000"',
#    'id': '1lhaju93vohkcamf2p1kmll91j_20200204',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWxoYWp1OTN2b2hrY2FtZjJwMWttbGw5MWpfMjAyMDAyMDQganVsaWVuQGJsYW5jaG9uLmNj',
#    'created': '2018-09-28T18:51:45.000Z',
#    'updated': '2019-09-04T17:35:12.867Z',
#    'summary': 'Facture Hetzner €27.23',
#    'description': '<a href="https://accounts.hetzner.com/invoice">https://accounts.hetzner.com/invoice</a>',
#    'location': 'Gunzenhausen, 91710 Gunzenhausen, Allemagne',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'date': '2020-02-04'},
#    'end': {'date': '2020-02-05'},
#    'recurringEventId': '1lhaju93vohkcamf2p1kmll91j',
#    'originalStartTime': {'date': '2020-02-04'},
#    'transparency': 'transparent',
#    'iCalUID': '1lhaju93vohkcamf2p1kmll91j@google.com',
#    'sequence': 0,
#    'extendedProperties': {'private': {'everyoneDeclinedDismissed': '-1'}},
#    'reminders': {'useDefault': False}},
#   {'kind': 'calendar#event',
#    'etag': '"3105779218368000"',
#    'id': '1lhaju93vohkcamf2p1kmll91j_20200304',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MWxoYWp1OTN2b2hrY2FtZjJwMWttbGw5MWpfMjAyMDAzMDQganVsaWVuQGJsYW5jaG9uLmNj',
#    'created': '2018-09-28T18:51:45.000Z',
#    'updated': '2019-09-04T17:35:12.867Z',
#    'summary': 'Facture Hetzner €27.23',
#    'description': '<a href="https://accounts.hetzner.com/invoice">https://accounts.hetzner.com/invoice</a>',
#    'location': 'Gunzenhausen, 91710 Gunzenhausen, Allemagne',
#    'creator': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'organizer': {'email': 'julien@blanchon.cc',
#     'displayName': 'Julien Blanchon',
#     'self': True},
#    'start': {'date': '2020-03-04'},
#    'end': {'date': '2020-03-05'},
#    'recurringEventId': '1lhaju93vohkcamf2p1kmll91j',
#    'originalStartTime': {'date': '2020-03-04'},
#    'transparency': 'transparent',
#    'iCalUID': '1lhaju93vohkcamf2p1kmll91j@google.com',
#    'sequence': 0,
#    'extendedProperties': {'private': {'everyoneDeclinedDismissed': '-1'}},
#    'reminders': {'useDefault': False}}]}
